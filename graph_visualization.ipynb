# %%
from collections import Mapping
import networkx as nx
import numpy as np

# %%
graph_data = {'ISOP1OHc': {'ISOP1OH2OO': 0.013360915758224843, 'ISOP': 0.0, 'ISOP1OH4OOc': 0.9866390842417752}, 'ISOP1OHt': {'ISOP1OH2OO': 0.09228001291704897, 'ISOP': 0.0, 'ISOP1OH4OOt': 0.907719987082951}, 'ISOP4OHc': {'ISOP1OO4OHc': 0.9859481883578269, 'ISOP': 0.0, 'ISOP3OO4OH': 0.01405181164217309}}

# %%
for k, d in graph_data.items():
    for ik in d:
        d[ik] = {'weight': d[ik]}

g = nx.DiGraph(graph_data)

# %%
np.random.seed(8)
nx.draw(g, with_labels=True)
